# %%
s = "hello"
print(s[0:4:-1])
print(s.center(11," "))
s1 = " hello "
print(s1.lstrip())
print(s1.rstrip())
# Out:
#    hello
# hello
#  hello

# %%
a = 10
b = 20
c = 8
#d = b.copy()
print(a)
print(b)
print(c)
#print(d)
print(a is c)
print(a is b)
# Out:
# 10
# 20
# 8
# False
# False

# %%
for i in range(1,6):
   for j in range(i):
       print("*",end="")
   print("")
# Out:
# *
# **
# ***
# ****
# *****

# %%
l = [1,2,3,4]
print(l)
# Out:
# [1, 2, 3, 4]

# %%
a =200
b = 200
print("A") if a>=b and a==b else print("B")
# Out:
# A

# %%
s="xxx"
for i,j in enumerate(s): # enumerate fun give the index from the given string
     print(i,j)
# Out:
# 0 x
# 1 x
# 2 x

# %%
food =["maggi","pizza","sandwitch"]
for i,f in enumerate(food):
 print(f"{i+1}:{f}")
# Out:
# 1:maggi
# 2:pizza
# 3:sandwitch

# %%
l.append(100)
print(l)
l = [1,"a",89]
print(l)
l.insert(0,55)
print(l)
# Out:
# [1, 2, 3, 4, 100]
# [1, 'a', 89]
# [55, 1, 'a', 89]

# %%
a=[]
a.append(12)
a.append(56)
print(a)
# Out:
# [12, 56]

# %%
a=[1,2,3,4]
b=[3,5,6]
a.append(b)
print(a)
# Out:
# [1, 2, 3, 4, [3, 5, 6]]

# %%
a=[10,20,30,40,40,50]
print(a.pop())
a.pop(2)
print(a)
# Out:
# 50
# [10, 20, 40, 40]

# %%
del a[3]
print(a)
# Out:
# [10, 20, 40]

# %%
a.remove(10)
#a.remove(200) #Error
print(a)
# Out:
# [20]

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry", "apple", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'cherry')

# %%
print(len(thistuple))
# Out:
# 5

# %%
thistuple = ("apple",)
print(type(thistuple))

#NOT a tuple
thistuple = ("apple")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
tuple1 = ("apple", "banana", "cherry")
tuple2 = (1, 5, 7, 9, 3)
tuple3 = (True, False, False)

# %%
tuple1 = ("abc", 34, True, 40, "male")

# %%
mytuple = ("apple", "banana", "cherry")
print(type(mytuple))
# Out:
# <class 'tuple'>

# %%
thistuple = tuple(("apple", "banana", "cherry")) # note the double round-brackets
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
t = (1, 2, 3, 4, 5)

# tuples are indexed
print(t[1])
print(t[4])

# tuples contain duplicate elements
t = (1, 2, 3, 4, 2, 3)
print(t)

# updating an element
t[1] = 100
print(t)
# Out:
# 2
# 5
# (1, 2, 3, 4, 2, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-6a56236e1460> in <cell line: 0>()
#      10
#      11 # updating an element
# ---> 12 t[1] = 100
#      13 print(t)
#
# TypeError: 'tuple' object does not support item assignment

# %%
t = (10, 5, 20)

print("Value in t[0] = ", t[0])
print("Value in t[1] = ", t[1])
print("Value in t[2] = ", t[2])
# Out:
# Value in t[0] =  10
# Value in t[1] =  5
# Value in t[2] =  20

# %%
t = (10, 5, 20)

print("Value in t[-1] = ", t[-1])
print("Value in t[-2] = ", t[-2])
print("Value in t[-3] = ", t[-3])
# Out:
# Value in t[-1] =  20
# Value in t[-2] =  5
# Value in t[-3] =  10

# %%
# Define a tuple
t = (1, 2, 3, 4, 5)

# Traverse through each item in the tuple
for x in t:
    print(x, end=" ")
# Out:
# 1 2 3 4 5

# %%
# Code for concatenating 2 tuples
t1 = (0, 1, 2, 3)
t2 = ('python', 'geek')

# Concatenating above two
print(t1 + t2)
# Out:
# (0, 1, 2, 3, 'python', 'geek')

# %%
# Code for creating nested tuples
t1 = (0, 1, 2, 3)
t2 = ('python', 'geek')

t3 = (t1, t2)
print(t3)
# Out:
# ((0, 1, 2, 3), ('python', 'geek'))

# %%
# Code to create a tuple with repetition
t = ('python',)*3
print(t)
# Out:
# ('python', 'python', 'python')

# %%
# code to test slicing
t = (0 ,1, 2, 3)

print(t[1:])
print(t[::-1])
print(t[2:4])
# Out:
# (1, 2, 3)
# (3, 2, 1, 0)
# (2, 3)

# %%
# Code for deleting a tuple
t = ( 0, 1)

del t
print(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-30f14c44bdb3> in <cell line: 0>()
#       3
#       4 del t
# ----> 5 print(t)
#
# NameError: name 't' is not defined

# %%
# Code for printing the length of a tuple
t = ('python', 'geek')
print(len(t))
# Out:
# 2

# %%
# tuple with different datatypes
t = ("immutable", True, 23)
print(t)
# Out:
# ('immutable', True, 23)

# %%
# Code for converting a list and a string into a tuple
a = [0, 1, 2]
t = tuple(a)

print(t)
# Out:
# (0, 1, 2)

# %%
# python code for creating tuples in a loop
t = ('gfg',)

# Number of time loop runs
n = 5
for i in range(int(n)):
    t = (t,)
    print(t)
# Out:
# (('gfg',),)
# ((('gfg',),),)
# (((('gfg',),),),)
# ((((('gfg',),),),),)
# (((((('gfg',),),),),),)

# %%
# Creating a tuple without brackets
t = 4, 5, 6
print(t)  # Output: (4, 5, 6)
# Out:
# (4, 5, 6)

# %%
# Creating a tuple using the tuple() constructor
t = tuple([7, 8, 9])
print(t)  # Output: (7, 8, 9)
# Out:
# (7, 8, 9)

# %%
# Creating an empty tuple
t = ()
print(t)  # Output: ()
# Out:
# ()

# %%
# Creating a single-element tuple
t = (10, ) # Comma is important here
print(t)  # Output: (10,)
print(type(t))

# What if we do not use comma
t = (10) # This an integer (not a tuple)
print(t)
print(type(t))
# Out:
# (10,)
# <class 'tuple'>
# 10
# <class 'int'>

# %%
# Tuple packing
a, b, c = 11, 12, 13
t = (a, b, c)
print(t)  # Output: (11, 12, 13)
# Out:
# (11, 12, 13)
